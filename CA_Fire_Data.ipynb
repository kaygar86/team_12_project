# %%
#Add the Pandas Dependency
import pandas as pd

# %%
#Files to load
fire_data_to_load = "California_Fire_Perimeters_(all).csv"

# %%
# Read the fire data file and store it in a Pandas DataFrame.
fire_data_df = pd.read_csv(fire_data_to_load)
fire_data_df
# Out:
#        OBJECTID   YEAR_ STATE AGENCY UNIT_ID      FIRE_NAME   INC_NUM  \
# 0         21440  2020.0    CA    CDF     NEU         NELSON  00013212
# 1         21441  2020.0    CA    CDF     NEU        AMORUSO  00011799
# 2         21442  2020.0    CA    CDF     NEU         ATHENS  00018493
# 3         21443  2020.0    CA    CDF     NEU        FLEMING  00007619
# 4         21444  2020.0    CA    CDF     NEU       MELANESE  00008471
# ...         ...     ...   ...    ...     ...            ...       ...
# 21681     43179  2021.0    CA    USF     SQF       BOYDEN 1  00000401
# 21682     43180  2021.0    CA    USF     INF  GLACIER NORTH  00001732
# 21683     43181  2021.0    CA    CCO     KRN       Backus 2  02118345
# 21684     43182  2021.0    CA    CDF     BTU          DIXIE  00009205
# 21685     43183  2021.0    CA    USF     KNF  RIVER COMPLEX  00006385
#
#                    ALARM_DATE               CONT_DATE  CAUSE  \
# 0      2020/06/18 00:00:00+00  2020/06/23 00:00:00+00   11.0
# ...
