# %%
#import packages
import pandas as pd
from pathlib import Path

# %%
# Files to load
food_facilities_df = pd.read_csv(('food_facilities_clean.csv'))
food_facilities_df
# Out:
#                                                    Name  \
# 0                                       Park Point Club
# 1                                        La Guadalupana
# 2                      Freestone Vineyards Guest Center
# 3                                   Girl & The Fig, The
# 4                                           Capt Daveys
# ...                                                 ...
# 3039                           Sonoma Eats Mexican Food
# 3040                                       The Lazy Hog
# 3041                                      Presto Fresco
# 3042  Sunflower Caffe Coffee & Baking Co. dba Honey ...
# 3043                                    Yogurtland #248
#
#                         Address        City State ZipCode
# 0             1200 N Dutton Ave  Santa Rosa    CA   95401
# 1            1031 Sebastopol Rd  Santa Rosa    CA   95407
# 2        12747 El Camino Bodega   Freestone    CA   95472
# ...

# %%
import numpy as np

# %%
food_facilities_df = food_facilities_df.groupby(['ZipCode'])['ZipCode'].count().reset_index(name='facilities_count')
food_facilities_df

# food_facilities_df = pd.pivot_table(food_facilities_df, values='Name', index=['ZipCode'],aggfunc=np.count)
# Out:
#    ZipCode  facilities_count
# 0     6213                 1
# 1    91952                 1
# 2    94501                 1
# 3    94515                 2
# 4    94523                 1
# ..     ...               ...
# 68   95480                 3
# 69   95492               131
# 70   95495                 1
# 71   95497                 3
# 72   95688                 1
#
# [73 rows x 2 columns]

# %%
# Out:
#                                                       Name
# ZipCode
# 6213                      Wood Lim Inc dba: Carrs Drive in
# 91952                           Taylor Maid Organic Coffee
# 94501                      Best of Burma 2 Burmese Cuisine
# 94515                   Mayacamas RanchMountain Home Ranch
# 94523                               Bodega Bay Hospitality
# ...                                                    ...
# 95480    Stewarts Point StoreKashia Elementary SchoolTw...
# 95492    Chinois Asian BistroWindsor Bowling CenterCali...
# 95495                                       Anna's Seafood
# 95497       Twofish Baking CoSea Ranch LodgeThe Ranch Cafe
# 95688                                            Holy Mo's
#
# [73 rows x 1 columns]
