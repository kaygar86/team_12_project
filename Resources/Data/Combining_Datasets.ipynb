# %%
import pandas as pd
from pathlib import Path

# %%
shelter_df = pd.read_csv(("Animal_Shelter_Intake_and_Outcome.csv"))
shelter_df.head()
# Out:
#   Name Type        Breed        Color     Sex   Size Date Of Birth  \
# 0  NaN  CAT      SIAMESE  BLACK/BLACK  Female  KITTN           NaN
# 1  NaN  CAT  DOMESTIC SH   GRAY/WHITE    Male  KITTN    06/24/2022
# 2  NaN  CAT      SIAMESE   GRAY/BLACK  Female  KITTN           NaN
# 3  NaN  CAT      SIAMESE   GRAY/BLACK  Female  KITTN           NaN
# 4  NaN  CAT  DOMESTIC SH        BLACK  Female  SMALL    12/30/2020
#
#   Impound Number Kennel Number Animal ID  ... Intake Subtype Outcome Type  \
# 0     K22-042204          CS05   A412797  ...          FIELD     TRANSFER
# 1     K22-042194          CA03   A412786  ...          PHONE          NaN
# 2     K22-042201          CS05   A412794  ...          FIELD     TRANSFER
# 3     K22-042202          CS05   A412795  ...          FIELD     TRANSFER
# 4     K22-041790           SMM   A412222  ...          FIELD     TRANSFER
#
#   Outcome Subtype Intake Condition Outcome Condition Intake Jurisdiction  \
# ...

# %%
facitilities_df = pd.read_csv(('food_facilities_clean_new.csv'))
facitilities_df.head()
# Out:
#   ZipCode  facilities_count
# 0    6213                 1
# 1   91952                 1
# 2   94501                 1
# 3   94515                 2
# 4   94523                 1

# %%
census_df = pd.read_csv(('Sonoma_County_CensusData_by Zip codes.csv'))
census_df.head()
# Out:
#    ZipCode Population Number of Households Median Income Average Income  \
# 0    95442      3,143                1,365       144,129        256,748
# 1    94922        726                  187       112,244        168,801
# 2    94515      7,525                2,772        85,263        165,466
# 3    95441      1,696                  659       111,198        141,612
# 4    95448     17,353                6,899        95,938        139,747
#
#    Land Area (Sq. Miles)  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0                   24.0         NaN         NaN         NaN         NaN
# 1                   12.0         NaN         NaN         NaN         NaN
# 2                  106.0         NaN         NaN         NaN         NaN
# 3                  102.0         NaN         NaN         NaN         NaN
# 4                  188.0         NaN         NaN         NaN         NaN
#
#    Unnamed: 10  Unnamed: 11  Unnamed: 12
# 0          NaN          NaN          NaN
# ...

# %%
weather_df = pd.read_csv(('sonoma_county_weather_clean.csv'))
weather_df.head()
# Out:
#    month_date  high_temp  low_temp   rain
# 0  2019-01-01         59        40   6.14
# 1  2019-02-01         54        38  15.03
# 2  2019-03-01         61        41   6.64
# 3  2019-04-01         68        45   1.03
# 4  2019-05-01         65        46   2.94

# %%
county_df = pd.read_csv(('zip_code_county_city_database.csv'))
county_df.head()
# Out:
#    zip      type  decommissioned primary_city acceptable_cities  \
# 0  501    UNIQUE               0   Holtsville               NaN
# 1  544    UNIQUE               0   Holtsville               NaN
# 2  601  STANDARD               0     Adjuntas               NaN
# 3  602  STANDARD               0       Aguada               NaN
# 4  603  STANDARD               0    Aguadilla             Ramey
#
#                                  unacceptable_cities state  \
# 0                           Internal Revenue Service    NY
# 1                           Internal Revenue Service    NY
# 2  Colinas Del Gigante, Jard De Adjuntas, Urb San...    PR
# 3  Alts De Aguada, Bo Guaniquilla, Comunidad Las ...    PR
# 4  Bda Caban, Bda Esteves, Bo Borinquen, Bo Ceiba...    PR
#
#                 county             timezone area_codes world_region country  \
# 0       Suffolk County     America/New_York        631          NaN      US
# ...

# %%
combined_data = pd.concat([shelter_df,facitilities_df,census_df,weather_df,county_df])
combined_data.head()
# Out:
#   Name Type        Breed        Color     Sex   Size Date Of Birth  \
# 0  NaN  CAT      SIAMESE  BLACK/BLACK  Female  KITTN           NaN
# 1  NaN  CAT  DOMESTIC SH   GRAY/WHITE    Male  KITTN    06/24/2022
# 2  NaN  CAT      SIAMESE   GRAY/BLACK  Female  KITTN           NaN
# 3  NaN  CAT      SIAMESE   GRAY/BLACK  Female  KITTN           NaN
# 4  NaN  CAT  DOMESTIC SH        BLACK  Female  SMALL    12/30/2020
#
#   Impound Number Kennel Number Animal ID  ... unacceptable_cities state  \
# 0     K22-042204          CS05   A412797  ...                 NaN   NaN
# 1     K22-042194          CA03   A412786  ...                 NaN   NaN
# 2     K22-042201          CS05   A412794  ...                 NaN   NaN
# 3     K22-042202          CS05   A412795  ...                 NaN   NaN
# 4     K22-041790           SMM   A412222  ...                 NaN   NaN
#
#   county timezone area_codes world_region country latitude longitude  \
# ...

# %%
combined_data.to_csv('C:/Users/lemuslau/Desktop/Boot Camp/team_12_project/Resources/Data/combined_data.csv', index = False, encoding='utf-8')  # Export merged pandas DataFrame
