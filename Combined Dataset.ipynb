# %%
#import packages
import pandas as pd
from pathlib import Path

# %%
# Files to load
shelter_df = pd.read_csv(('sonoma_shelter_clean.csv'))
shelter_df
# Out:
#       Animal ID Animal Type             Breed   Size Intake Date  \
# 0       A412797         CAT           SIAMESE  KITTN  08/08/2022
# 1       A412786         CAT       DOMESTIC SH  KITTN  08/09/2022
# 2       A412794         CAT           SIAMESE  KITTN  08/08/2022
# 3       A412795         CAT           SIAMESE  KITTN  08/08/2022
# 4       A412222         CAT       DOMESTIC SH  SMALL  06/30/2022
# ...         ...         ...               ...    ...         ...
# 21567   A351065         DOG  CHIHUAHUA SH/MIX  SMALL  04/12/2017
# 21568   A346283         CAT       DOMESTIC SH  SMALL  12/15/2016
# 21569   A319531         CAT       DOMESTIC MH  SMALL  03/28/2015
# 21570   A315809         DOG     SCHNAUZER MIN  SMALL  08/26/2017
# 21571   A321648         DOG     GERM SHEPHERD  LARGE  05/14/2015
#
#           Outcome Type  Outcome Zip Code Intake Jurisdiction  \
# 0             TRANSFER           95403.0          SANTA ROSA
# ...

# %%
facitilities_df = pd.read_csv(('food_facilities_clean.csv'))
facitilities_df
# Out:
#                                                    Name  \
# 0                                       Park Point Club
# 1                                        La Guadalupana
# 2                      Freestone Vineyards Guest Center
# 3                                   Girl & The Fig, The
# 4                                           Capt Daveys
# ...                                                 ...
# 3039                           Sonoma Eats Mexican Food
# 3040                                       The Lazy Hog
# 3041                                      Presto Fresco
# 3042  Sunflower Caffe Coffee & Baking Co. dba Honey ...
# 3043                                    Yogurtland #248
#
#                         Address        City State ZipCode
# 0             1200 N Dutton Ave  Santa Rosa    CA   95401
# 1            1031 Sebastopol Rd  Santa Rosa    CA   95407
# 2        12747 El Camino Bodega   Freestone    CA   95472
# ...

# %%
census_df = pd.read_csv(('Sonoma_County_CensusData_by Zip codes.csv'))
census_df
# Out:
#     ZipCode Population Number of Households Median Income Average Income  \
# 0     95442      3,143                1,365       144,129        256,748
# 1     94922        726                  187       112,244        168,801
# 2     94515      7,525                2,772        85,263        165,466
# 3     95441      1,696                  659       111,198        141,612
# 4     95448     17,353                6,899        95,938        139,747
# 5     94923      1,185                  545        66,975        134,882
# 6     94952     35,198               13,834        92,314        131,389
# 7     95492     29,502                9,915       118,773        128,386
# 8     95476     37,150               15,591        87,374        125,265
# 9     95472     29,690               12,171        95,417        120,021
# 10    95404     38,462               15,647        86,555        118,799
# 11    94954     39,018               13,878        95,724        117,619
# ...

# %%
weather_df = pd.read_csv(('sonoma_county_weather_clean.csv'))
weather_df
# Out:
#     month_date  high_temp  low_temp   rain
# 0   2019-01-01         59        40   6.14
# 1   2019-02-01         54        38  15.03
# 2   2019-03-01         61        41   6.64
# 3   2019-04-01         68        45   1.03
# 4   2019-05-01         65        46   2.94
# 5   2019-06-01         77        49   0.29
# 6   2019-07-01         80        50   0.74
# 7   2019-08-01         83        52   0.46
# 8   2019-09-01         82        47   0.19
# 9   2019-10-01         78        37   0.06
# 10  2019-11-01         68        36   1.47
# 11  2019-12-01         57        42   7.01
# 12  2020-01-01         58        37   1.94
# 13  2020-02-01         67        35   0.01
# 14  2020-03-01         61        38   1.39
# 15  2020-04-01         68        40   1.06
# 16  2020-05-01         73        45   1.08
# 17  2020-06-01         78        48   0.06
# 18  2020-07-01         78        50   0.02
# 19  2020-08-01         83        52   0.16
# 20  2020-09-01         84        50   0.54
# ...

# %%
result_df = shelter_df.join(census_df, on=["Outcome Zip Code", "ZipCode"], how="left")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_37612\4193510869.py in <module>
# ----> 1 result_df = shelter_df.join(census_df, on=["Outcome Zip Code", "ZipCode"], how="left")
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    9098         """
#    9099         return self._join_compat(
# -> 9100             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9101         )
#    9102
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    9136                 right_index=True,
#    9137                 suffixes=(lsuffix, rsuffix),
# -> 9138                 sort=sort,
#    9139             )
#    9140         else:
#
# ...
